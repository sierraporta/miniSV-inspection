# %%
# %pylab inline
import desispec
import desitarget
import desimodel.io
print('desimodel ', desimodel.__version__)
print('desispec  ', desispec.__version__)
print('desitarget', desitarget.__version__)

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from astropy.table import Table, vstack, hstack
import fitsio
import glob
import os
# %matplotlib inline
# Out:
# Populating the interactive namespace from numpy and matplotlib
# desimodel  0.12.0.dev597
# desispec   0.33.0.dev3890
# desitarget 0.37.0.dev3908

# %% [markdown]
# # Data for observation conditions of miniSV2 and SVo tiles commisioning.

# %%
path_cond_comisioning="/global/cfs/cdirs/desi/users/ameisner/GFA/conditions/"

# %%
os.listdir(path_cond_comisioning)
# Out:
# ['offline_all_guide_ccds_SV0.fits',
#  'offline_all_guide_ccds_thru_20200315.fits',
#  'offline_all_guide_ccds_minisv2.fits']

# %%
print("Night conditions for minisv2: "+os.listdir(path_cond_comisioning)[2])
print("Night conditions for SV0: "+os.listdir(path_cond_comisioning)[0])
print("Night conditions for all commissioning: "+os.listdir(path_cond_comisioning)[1])
# Out:
# Night conditions for minisv2: offline_all_guide_ccds_minisv2.fits
# Night conditions for SV0: offline_all_guide_ccds_SV0.fits
# Night conditions for all commissioning: offline_all_guide_ccds_thru_20200315.fits

# %%
#!fitsheader /global/cfs/cdirs/desi/users/ameisner/GFA/conditions/offline_all_guide_ccds_minisv2.fits

# %%
cond_SV0=Table(fitsio.read("/global/cfs/cdirs/desi/users/ameisner/GFA/conditions/offline_all_guide_ccds_SV0.fits", ext=1))
cond_SV2=Table(fitsio.read("/global/cfs/cdirs/desi/users/ameisner/GFA/conditions/offline_all_guide_ccds_minisv2.fits", ext=1))

cond_SV2.columns
# Out:
# <TableColumns names=('MEDIAN','MEAN','N_NON_FINITE','MAX','MIN','SIG_ROBUST','SIG','MEDIAN_Q1','MEAN_Q1','N_NON_FINITE_Q1','MAX_Q1','MIN_Q1','SIG_ROBUST_Q1','SIG_Q1','MEDIAN_Q2','MEAN_Q2','N_NON_FINITE_Q2','MAX_Q2','MIN_Q2','SIG_ROBUST_Q2','SIG_Q2','MEDIAN_Q3','MEAN_Q3','N_NON_FINITE_Q3','MAX_Q3','MIN_Q3','SIG_ROBUST_Q3','SIG_Q3','MEDIAN_Q4','MEAN_Q4','N_NON_FINITE_Q4','MAX_Q4','MIN_Q4','SIG_ROBUST_Q4','SIG_Q4','CAMERA','SKY_MAG_AB','SKY_MAG_AB_PER_AMP','PETAL_LOC','EXPID','MJD','PROGRAM','SKYRA','SKYDEC','DOMSHUTL','DOMSHUTU','PMCOVER','MOONRA','MOONDEC','T_C_FOR_DARK','T_C_FOR_DARK_IS_GUESS','TIME_S_FOR_DARK','AIRMASS','NIGHT','FOCUS','EXPTIME','CUBE_INDEX','RACEN','DECCEN','FNAME_RAW','GITREV','EXTNAME','CONTRAST','FIBER_FRACFLUX','N_SOURCES_FOR_PSF','APER_CORR_FAC','XCENTROID_PSF','YCENTROID_PSF','MOON_SEP_DEG','ZP_ADU_PER_S','TRANSPARENCY','NPIX_BAD_TOTAL','NPIX_BAD_PER_AMP','OVERSCAN_MEDIANS_ADU','PRESCAN_MEDIANS_ADU','FWHM_MAJOR_PIX','FWHM_MINOR_PIX','FWHM_PIX','FWHM_ASEC','N_SOURCES','NAXIS','CD','CDELT','CRPIX','CRVAL','CTYPE','LONGPOLE','LATPOLE','PV2','FNAME_MASTER_DARK','DO_FIT_DARK_SCALING','MASTER_DARK_EXPTIME','MASTER_DARK_GCCDTEMP','DARK_TEMP_SCALING_FACTOR','TOTAL_DARK_SCALING_FACTOR','DARK_RESCALE_FACTORS_PER_AMP','DARK_RESCALE_FACTOR_BESTFIT','DARK_RESCALE_FACTOR_ADOPTED','APPLY_DARK_RESCALE_FACTOR','DARK_RESCALE_NCALLS','DARK_RESCALE_CONVERGED','SPECTRO_EXPID')>

# %%
pd.DataFrame(np.unique(cond_SV2["NIGHT"],return_counts=True))
# Out:
#           0         1         2         3         4         5         6  \
# 0  20200219  20200220  20200224  20200225  20200226  20200227  20200228
# 1     12138      3378      5520      6342      8250      6912      8646
#
#           7         8         9
# 0  20200229  20200303  20200304
# 1      1104     11250     13062

# %% [markdown]
# # Data for coadds miniSV2 and SV0 tiles commisioning (BGS objects).

# %%
### BGS objects.
path_coadds="/global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/"

# %%
unique_days=np.unique(cond_SV2["NIGHT"])
unique_spectro_id=np.unique(cond_SV2["SPECTRO_EXPID"])

# %%
for filename in os.listdir(path_coadds):
    for j in unique_days:
        if filename.endswith(".fits") and "20200225" in filename and 'coadd' in filename and '00052112' in filename and '-7-' in filename:
            print(filename)
        else:
            continue
# Out:
# coadd-70502-20200225-7-00052112.fits
# coadd-70502-20200225-7-00052112.fits
# coadd-70502-20200225-7-00052112.fits
# coadd-70502-20200225-7-00052112.fits
# coadd-70502-20200225-7-00052112.fits
# coadd-70502-20200225-7-00052112.fits
# coadd-70502-20200225-7-00052112.fits
# coadd-70502-20200225-7-00052112.fits
# coadd-70502-20200225-7-00052112.fits
# coadd-70502-20200225-7-00052112.fits

# %%
data_vis=Table(fitsio.read("/global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-66014-20200314-1-00055432.fits", ext=1))
np.unique(data_vis["OBJTYPE"])
# Out:
# <Column name='OBJTYPE' dtype='bytes3' length=2>
# SKY
# TGT

# %%
cond_SV2[(cond_SV2["NIGHT"]==20200225)&(cond_SV2["SPECTRO_EXPID"]==52112)&(cond_SV2["PETAL_LOC"]==7)][0:5].columns
# Out:
# <TableColumns names=('MEDIAN','MEAN','N_NON_FINITE','MAX','MIN','SIG_ROBUST','SIG','MEDIAN_Q1','MEAN_Q1','N_NON_FINITE_Q1','MAX_Q1','MIN_Q1','SIG_ROBUST_Q1','SIG_Q1','MEDIAN_Q2','MEAN_Q2','N_NON_FINITE_Q2','MAX_Q2','MIN_Q2','SIG_ROBUST_Q2','SIG_Q2','MEDIAN_Q3','MEAN_Q3','N_NON_FINITE_Q3','MAX_Q3','MIN_Q3','SIG_ROBUST_Q3','SIG_Q3','MEDIAN_Q4','MEAN_Q4','N_NON_FINITE_Q4','MAX_Q4','MIN_Q4','SIG_ROBUST_Q4','SIG_Q4','CAMERA','SKY_MAG_AB','SKY_MAG_AB_PER_AMP','PETAL_LOC','EXPID','MJD','PROGRAM','SKYRA','SKYDEC','DOMSHUTL','DOMSHUTU','PMCOVER','MOONRA','MOONDEC','T_C_FOR_DARK','T_C_FOR_DARK_IS_GUESS','TIME_S_FOR_DARK','AIRMASS','NIGHT','FOCUS','EXPTIME','CUBE_INDEX','RACEN','DECCEN','FNAME_RAW','GITREV','EXTNAME','CONTRAST','FIBER_FRACFLUX','N_SOURCES_FOR_PSF','APER_CORR_FAC','XCENTROID_PSF','YCENTROID_PSF','MOON_SEP_DEG','ZP_ADU_PER_S','TRANSPARENCY','NPIX_BAD_TOTAL','NPIX_BAD_PER_AMP','OVERSCAN_MEDIANS_ADU','PRESCAN_MEDIANS_ADU','FWHM_MAJOR_PIX','FWHM_MINOR_PIX','FWHM_PIX','FWHM_ASEC','N_SOURCES','NAXIS','CD','CDELT','CRPIX','CRVAL','CTYPE','LONGPOLE','LATPOLE','PV2','FNAME_MASTER_DARK','DO_FIT_DARK_SCALING','MASTER_DARK_EXPTIME','MASTER_DARK_GCCDTEMP','DARK_TEMP_SCALING_FACTOR','TOTAL_DARK_SCALING_FACTOR','DARK_RESCALE_FACTORS_PER_AMP','DARK_RESCALE_FACTOR_BESTFIT','DARK_RESCALE_FACTOR_ADOPTED','APPLY_DARK_RESCALE_FACTOR','DARK_RESCALE_NCALLS','DARK_RESCALE_CONVERGED','SPECTRO_EXPID')>

# %%
#!fitsheader /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-70502-20200225-7-00052112.fits

# %% [markdown]
# ## Get all tiles, night (days), petals and expid for all coadd availables.

# %% [markdown]
# ### To measure the signal / noise ratio, we take the interval of the first 1/3 of the spectrum at the lowest wavelengths and calculate the mean value (μ) and also the standard deviation (σ). So from here we get a measure of
#
# $$SN_{frac}=P_{signal}/P_{noise}=\mu/\sigma, $$

# %%
tile,day,petalloc,expid,SN_frac,SN_z_spec,SN_z,SN_z_std=[],[],[],[],[],[],[],[]
means_spec,std_spec=[],[]
for filename in os.listdir(path_coadds):
    if filename.endswith(".fits") and 'coadd' in filename:
        #print("found a coadds:")
        print("found a coadds:",path_coadds+filename)
        zbest=Table(fitsio.read(path_coadds+"zbest"+filename[5:], ext=1))
        data=Table(fitsio.read(path_coadds+filename, ext=1))
        #IF ONLY I WANT SKY ("SKY") OR TARGET ("TGT") OBJECTS
        issky=data["OBJTYPE"]=="SKY"
        istgt=data["OBJTYPE"]=="TGT"
        isgalaxy=zbest["SPECTYPE"]=="GALAXY"
        isqso=zbest["SPECTYPE"]=="QSO"
        isstar=zbest["SPECTYPE"]=="STAR"
        index_sky=np.where(issky)
        index_tgt=np.where(istgt)
        index_galaxy=np.where(isgalaxy)
        index_qso=np.where(isqso)
        index_star=np.where(isstar)
        #print(index_sky)
        data3=fitsio.read(path_coadds+filename, ext=3)
        
        for i in np.intersect1d(index_sky,index_star):
            len_data=round(len(data3)/3)
            #print(i, abs(np.nanmean(data3[i][0:len_data])/np.nanstd(data3[i][0:len_data],ddof=1)))
            SN_z_spec.append(abs(np.nanmean(data3[i][0:len_data])/np.nanstd(data3[i][0:len_data],ddof=1)))
        #print("For coadd: ",filename,"S/N fraction is = ",len(data)/len(data[issky]))
        print("For coadd: ",filename,"SN_z_spec fraction is = ",np.nanmean(SN_z_spec))
        name=filename
        tile.append(name.split("-")[1])
        day.append(name.split("-")[2])
        petalloc.append(name.split("-")[3])
        expid.append(name.split("-")[4][3:-5])
        SN_frac.append(len(data)/len(data[issky]))
        SN_z.append(np.nanmean(SN_z_spec))
        SN_z_std.append(np.nanstd(SN_z_spec)/np.sqrt(len(SN_z_spec)))
    else:
        continue
tile,day,petalloc,expid,SN_frac,SN_z,SN_z_std=np.array(tile),np.array(day),np.array(petalloc),np.array(expid),np.array(SN_frac),np.array(SN_z),np.array(SN_z_std)
# Out:
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-66000-20200314-7-00055442.fits
# For coadd:  coadd-66000-20200314-7-00055442.fits SN_z_spec fraction is =  nan
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-70510-20200304-6-00053082.fits
# For coadd:  coadd-70510-20200304-6-00053082.fits SN_z_spec fraction is =  nan
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-66000-20200314-0-00055442.fits
# /global/common/software/desi/cori/desiconda/20190804-1.3.0-spec/conda/lib/python3.6/site-packages/ipykernel/__main__.py:26: RuntimeWarning: invalid value encountered in float_scalars
# /global/common/software/desi/cori/desiconda/20190804-1.3.0-spec/conda/lib/python3.6/site-packages/ipykernel/__main__.py:28: RuntimeWarning: Mean of empty slice
# /global/common/software/desi/cori/desiconda/20190804-1.3.0-spec/conda/lib/python3.6/site-packages/ipykernel/__main__.py:35: RuntimeWarning: Mean of empty slice
# /global/common/software/desi/cori/desiconda/20190804-1.3.0-spec/conda/lib/python3.6/site-packages/numpy/lib/nanfunctions.py:1628: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   keepdims=keepdims)
# For coadd:  coadd-66000-20200314-0-00055442.fits SN_z_spec fraction is =  nan
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-66014-20200314-8-00055435.fits
# For coadd:  coadd-66014-20200314-8-00055435.fits SN_z_spec fraction is =  0.6373678
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-66000-20200314-5-00055442.fits
# For coadd:  coadd-66000-20200314-5-00055442.fits SN_z_spec fraction is =  0.6373678
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-70500-20200303-6-00052938.fits
# For coadd:  coadd-70500-20200303-6-00052938.fits SN_z_spec fraction is =  0.4277121
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-70500-20200303-6-00052935.fits
# For coadd:  coadd-70500-20200303-6-00052935.fits SN_z_spec fraction is =  0.4277121
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-70510-20200304-3-00053086.fits
# For coadd:  coadd-70510-20200304-3-00053086.fits SN_z_spec fraction is =  0.4277121
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-66014-20200314-5-00055432.fits
# For coadd:  coadd-66014-20200314-5-00055432.fits SN_z_spec fraction is =  0.4277121
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-66000-20200314-9-00055444.fits
# For coadd:  coadd-66000-20200314-9-00055444.fits SN_z_spec fraction is =  0.4277121
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-66003-20200315-2-00055654.fits
# For coadd:  coadd-66003-20200315-2-00055654.fits SN_z_spec fraction is =  0.4277121
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-66000-20200314-8-00055443.fits
# For coadd:  coadd-66000-20200314-8-00055443.fits SN_z_spec fraction is =  0.5418251
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-66003-20200315-3-00055656.fits
# For coadd:  coadd-66003-20200315-3-00055656.fits SN_z_spec fraction is =  0.5418251
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-70502-20200225-9-00052112.fits
# For coadd:  coadd-70502-20200225-9-00052112.fits SN_z_spec fraction is =  0.5418251
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-66000-20200314-5-00055443.fits
# For coadd:  coadd-66000-20200314-5-00055443.fits SN_z_spec fraction is =  0.5418251
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-70502-20200225-7-00052112.fits
# For coadd:  coadd-70502-20200225-7-00052112.fits SN_z_spec fraction is =  0.5418251
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-66014-20200314-0-00055432.fits
# For coadd:  coadd-66014-20200314-0-00055432.fits SN_z_spec fraction is =  0.5418251
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-66014-20200314-1-00055432.fits
# For coadd:  coadd-66014-20200314-1-00055432.fits SN_z_spec fraction is =  0.5418251
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-70500-20200303-6-00052940.fits
# For coadd:  coadd-70500-20200303-6-00052940.fits SN_z_spec fraction is =  0.5123941
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-66003-20200315-7-00055654.fits
# For coadd:  coadd-66003-20200315-7-00055654.fits SN_z_spec fraction is =  0.5123941
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-70510-20200304-3-00053083.fits
# For coadd:  coadd-70510-20200304-3-00053083.fits SN_z_spec fraction is =  0.512394
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-66014-20200314-8-00055432.fits
# For coadd:  coadd-66014-20200314-8-00055432.fits SN_z_spec fraction is =  0.49504676
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-66014-20200314-9-00055433.fits
# For coadd:  coadd-66014-20200314-9-00055433.fits SN_z_spec fraction is =  0.49504676
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-70500-20200303-9-00052937.fits
# For coadd:  coadd-70500-20200303-9-00052937.fits SN_z_spec fraction is =  0.49504676
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-70510-20200304-0-00053086.fits
# For coadd:  coadd-70510-20200304-0-00053086.fits SN_z_spec fraction is =  0.48574865
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-70500-20200303-9-00052935.fits
# For coadd:  coadd-70500-20200303-9-00052935.fits SN_z_spec fraction is =  0.48574865
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-70500-20200303-7-00052942.fits
# For coadd:  coadd-70500-20200303-7-00052942.fits SN_z_spec fraction is =  0.48574865
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-66000-20200314-9-00055445.fits
# For coadd:  coadd-66000-20200314-9-00055445.fits SN_z_spec fraction is =  0.48574865
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-70510-20200304-7-00053082.fits
# For coadd:  coadd-70510-20200304-7-00053082.fits SN_z_spec fraction is =  0.48574865
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-66014-20200314-3-00055434.fits
# For coadd:  coadd-66014-20200314-3-00055434.fits SN_z_spec fraction is =  0.48574865
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-70510-20200304-9-00053081.fits
# For coadd:  coadd-70510-20200304-9-00053081.fits SN_z_spec fraction is =  0.48574865
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-70500-20200303-9-00052934.fits
# For coadd:  coadd-70500-20200303-9-00052934.fits SN_z_spec fraction is =  0.48574865
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-66014-20200314-4-00055432.fits
# For coadd:  coadd-66014-20200314-4-00055432.fits SN_z_spec fraction is =  0.48574865
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-70502-20200225-6-00052115.fits
# For coadd:  coadd-70502-20200225-6-00052115.fits SN_z_spec fraction is =  0.48574865
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-70510-20200304-7-00053081.fits
# For coadd:  coadd-70510-20200304-7-00053081.fits SN_z_spec fraction is =  0.47596195
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-66003-20200315-5-00055656.fits
# For coadd:  coadd-66003-20200315-5-00055656.fits SN_z_spec fraction is =  0.47596195
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-70500-20200303-0-00052937.fits
# For coadd:  coadd-70500-20200303-0-00052937.fits SN_z_spec fraction is =  0.47596195
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-66000-20200314-2-00055443.fits
# For coadd:  coadd-66000-20200314-2-00055443.fits SN_z_spec fraction is =  0.47596195
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-66000-20200314-4-00055445.fits
# For coadd:  coadd-66000-20200314-4-00055445.fits SN_z_spec fraction is =  0.47596195
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-70510-20200304-0-00053089.fits
# For coadd:  coadd-70510-20200304-0-00053089.fits SN_z_spec fraction is =  0.47596195
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-70510-20200304-3-00053081.fits
# For coadd:  coadd-70510-20200304-3-00053081.fits SN_z_spec fraction is =  0.47596195
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-70500-20200303-3-00052942.fits
# For coadd:  coadd-70500-20200303-3-00052942.fits SN_z_spec fraction is =  0.47596195
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-66003-20200315-1-00055655.fits
# For coadd:  coadd-66003-20200315-1-00055655.fits SN_z_spec fraction is =  0.47596195
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-66014-20200314-7-00055432.fits
# For coadd:  coadd-66014-20200314-7-00055432.fits SN_z_spec fraction is =  0.47596198
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-70510-20200304-7-00053080.fits
# For coadd:  coadd-70510-20200304-7-00053080.fits SN_z_spec fraction is =  0.47596198
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-66014-20200314-9-00055432.fits
# For coadd:  coadd-66014-20200314-9-00055432.fits SN_z_spec fraction is =  0.46453902
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-66014-20200314-2-00055435.fits
# For coadd:  coadd-66014-20200314-2-00055435.fits SN_z_spec fraction is =  0.46064597
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-66014-20200314-3-00055435.fits
# For coadd:  coadd-66014-20200314-3-00055435.fits SN_z_spec fraction is =  0.460646
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-70510-20200304-9-00053082.fits
# For coadd:  coadd-70510-20200304-9-00053082.fits SN_z_spec fraction is =  0.460646
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-66003-20200315-6-00055654.fits
# For coadd:  coadd-66003-20200315-6-00055654.fits SN_z_spec fraction is =  0.460646
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-66003-20200315-8-00055655.fits
# For coadd:  coadd-66003-20200315-8-00055655.fits SN_z_spec fraction is =  0.47124672
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-70500-20200303-7-00052938.fits
# For coadd:  coadd-70500-20200303-7-00052938.fits SN_z_spec fraction is =  0.47124672
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-70510-20200304-6-00053078.fits
# For coadd:  coadd-70510-20200304-6-00053078.fits SN_z_spec fraction is =  0.47124672
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-70510-20200304-3-00053087.fits
# For coadd:  coadd-70510-20200304-3-00053087.fits SN_z_spec fraction is =  0.47124672
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-66014-20200314-0-00055435.fits
# For coadd:  coadd-66014-20200314-0-00055435.fits SN_z_spec fraction is =  0.47124672
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-70510-20200304-6-00053089.fits
# For coadd:  coadd-70510-20200304-6-00053089.fits SN_z_spec fraction is =  0.47124672
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-70502-20200225-6-00052116.fits
# For coadd:  coadd-70502-20200225-6-00052116.fits SN_z_spec fraction is =  0.47124672
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-70502-20200225-9-00052114.fits
# For coadd:  coadd-70502-20200225-9-00052114.fits SN_z_spec fraction is =  0.47124672
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-66014-20200314-3-00055432.fits
# For coadd:  coadd-66014-20200314-3-00055432.fits SN_z_spec fraction is =  0.47124672
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-70510-20200304-3-00053088.fits
# For coadd:  coadd-70510-20200304-3-00053088.fits SN_z_spec fraction is =  0.47124672
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-70510-20200304-7-00053088.fits
# For coadd:  coadd-70510-20200304-7-00053088.fits SN_z_spec fraction is =  0.47124672
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-70500-20200303-9-00052938.fits
# For coadd:  coadd-70500-20200303-9-00052938.fits SN_z_spec fraction is =  0.47124672
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-70502-20200225-7-00052116.fits
# For coadd:  coadd-70502-20200225-7-00052116.fits SN_z_spec fraction is =  0.47124672
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-70510-20200304-0-00053083.fits
# For coadd:  coadd-70510-20200304-0-00053083.fits SN_z_spec fraction is =  0.47124672
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-66014-20200314-6-00055433.fits
# For coadd:  coadd-66014-20200314-6-00055433.fits SN_z_spec fraction is =  0.47124672
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-70502-20200225-9-00052116.fits
# For coadd:  coadd-70502-20200225-9-00052116.fits SN_z_spec fraction is =  0.47124672
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-70502-20200225-3-00052090.fits
# For coadd:  coadd-70502-20200225-3-00052090.fits SN_z_spec fraction is =  0.47124672
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-66003-20200315-8-00055656.fits
# For coadd:  coadd-66003-20200315-8-00055656.fits SN_z_spec fraction is =  0.47124672
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-66000-20200314-2-00055442.fits
# For coadd:  coadd-66000-20200314-2-00055442.fits SN_z_spec fraction is =  0.47124666
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-70502-20200225-0-00052090.fits
# For coadd:  coadd-70502-20200225-0-00052090.fits SN_z_spec fraction is =  0.47124666
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-66000-20200314-4-00055444.fits
# For coadd:  coadd-66000-20200314-4-00055444.fits SN_z_spec fraction is =  0.47124666
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-66000-20200314-4-00055443.fits
# For coadd:  coadd-66000-20200314-4-00055443.fits SN_z_spec fraction is =  0.47124666
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-66003-20200315-3-00055655.fits
# For coadd:  coadd-66003-20200315-3-00055655.fits SN_z_spec fraction is =  0.47124666
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-70510-20200304-6-00053088.fits
# For coadd:  coadd-70510-20200304-6-00053088.fits SN_z_spec fraction is =  0.47124666
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-70502-20200225-7-00052090.fits
# For coadd:  coadd-70502-20200225-7-00052090.fits SN_z_spec fraction is =  0.47124666
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-70500-20200303-9-00052936.fits
# For coadd:  coadd-70500-20200303-9-00052936.fits SN_z_spec fraction is =  0.47124666
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-70500-20200303-7-00052933.fits
# For coadd:  coadd-70500-20200303-7-00052933.fits SN_z_spec fraction is =  0.47124666
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-70500-20200303-7-00052937.fits
# For coadd:  coadd-70500-20200303-7-00052937.fits SN_z_spec fraction is =  0.46806717
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-70500-20200303-6-00052941.fits
# For coadd:  coadd-70500-20200303-6-00052941.fits SN_z_spec fraction is =  0.46806717
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-70502-20200225-3-00052113.fits
# For coadd:  coadd-70502-20200225-3-00052113.fits SN_z_spec fraction is =  0.46806717
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-70500-20200303-7-00052943.fits
# For coadd:  coadd-70500-20200303-7-00052943.fits SN_z_spec fraction is =  0.46806717
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-70502-20200225-6-00052112.fits
# For coadd:  coadd-70502-20200225-6-00052112.fits SN_z_spec fraction is =  0.46806717
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-70510-20200304-6-00053085.fits
# For coadd:  coadd-70510-20200304-6-00053085.fits SN_z_spec fraction is =  0.46806717
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-66014-20200314-7-00055434.fits
# For coadd:  coadd-66014-20200314-7-00055434.fits SN_z_spec fraction is =  0.46806717
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-66000-20200314-1-00055443.fits
# For coadd:  coadd-66000-20200314-1-00055443.fits SN_z_spec fraction is =  0.46823996
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-66014-20200314-8-00055434.fits
# For coadd:  coadd-66014-20200314-8-00055434.fits SN_z_spec fraction is =  0.49344596
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-66014-20200314-4-00055435.fits
# For coadd:  coadd-66014-20200314-4-00055435.fits SN_z_spec fraction is =  0.49344596
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-66003-20200315-2-00055656.fits
# For coadd:  coadd-66003-20200315-2-00055656.fits SN_z_spec fraction is =  0.49344602
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-70502-20200225-6-00052114.fits
# For coadd:  coadd-70502-20200225-6-00052114.fits SN_z_spec fraction is =  0.49344602
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-70502-20200225-0-00052112.fits
# For coadd:  coadd-70502-20200225-0-00052112.fits SN_z_spec fraction is =  0.49344602
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-66003-20200315-1-00055654.fits
# For coadd:  coadd-66003-20200315-1-00055654.fits SN_z_spec fraction is =  0.49344596
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-66000-20200314-6-00055444.fits
# For coadd:  coadd-66000-20200314-6-00055444.fits SN_z_spec fraction is =  0.48629105
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-66003-20200315-5-00055655.fits
# For coadd:  coadd-66003-20200315-5-00055655.fits SN_z_spec fraction is =  0.48629108
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-70502-20200225-9-00052090.fits
# For coadd:  coadd-70502-20200225-9-00052090.fits SN_z_spec fraction is =  0.48629108
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-70510-20200304-9-00053084.fits
# For coadd:  coadd-70510-20200304-9-00053084.fits SN_z_spec fraction is =  0.48629108
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-70500-20200303-7-00052939.fits
# For coadd:  coadd-70500-20200303-7-00052939.fits SN_z_spec fraction is =  0.48629108
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-70502-20200225-6-00052113.fits
# For coadd:  coadd-70502-20200225-6-00052113.fits SN_z_spec fraction is =  0.48043942
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-70510-20200304-0-00053085.fits
# For coadd:  coadd-70510-20200304-0-00053085.fits SN_z_spec fraction is =  0.48043942
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-70502-20200225-3-00052114.fits
# For coadd:  coadd-70502-20200225-3-00052114.fits SN_z_spec fraction is =  0.48043945
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-70500-20200303-7-00052935.fits
# For coadd:  coadd-70500-20200303-7-00052935.fits SN_z_spec fraction is =  0.47352394
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-70500-20200303-7-00052934.fits
# For coadd:  coadd-70500-20200303-7-00052934.fits SN_z_spec fraction is =  0.47352394
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-66000-20200314-0-00055443.fits
# For coadd:  coadd-66000-20200314-0-00055443.fits SN_z_spec fraction is =  0.47352394
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-70500-20200303-9-00052933.fits
# For coadd:  coadd-70500-20200303-9-00052933.fits SN_z_spec fraction is =  0.47352394
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-70500-20200303-6-00052934.fits
# For coadd:  coadd-70500-20200303-6-00052934.fits SN_z_spec fraction is =  0.4735239
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-70502-20200225-3-00052115.fits
# For coadd:  coadd-70502-20200225-3-00052115.fits SN_z_spec fraction is =  0.47352394
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-66000-20200314-6-00055442.fits
# For coadd:  coadd-66000-20200314-6-00055442.fits SN_z_spec fraction is =  0.47352394
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-70510-20200304-9-00053080.fits
# For coadd:  coadd-70510-20200304-9-00053080.fits SN_z_spec fraction is =  0.47802705
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-66003-20200315-6-00055655.fits
# For coadd:  coadd-66003-20200315-6-00055655.fits SN_z_spec fraction is =  0.47802705
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-70510-20200304-9-00053090.fits
# For coadd:  coadd-70510-20200304-9-00053090.fits SN_z_spec fraction is =  0.47802705
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-70510-20200304-9-00053086.fits
# For coadd:  coadd-70510-20200304-9-00053086.fits SN_z_spec fraction is =  0.47802705
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-70510-20200304-3-00053085.fits
# For coadd:  coadd-70510-20200304-3-00053085.fits SN_z_spec fraction is =  0.47802705
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-70502-20200225-0-00052115.fits
# For coadd:  coadd-70502-20200225-0-00052115.fits SN_z_spec fraction is =  0.47802705
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-66003-20200315-4-00055654.fits
# For coadd:  coadd-66003-20200315-4-00055654.fits SN_z_spec fraction is =  0.47802705
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-70500-20200303-0-00052943.fits
# For coadd:  coadd-70500-20200303-0-00052943.fits SN_z_spec fraction is =  0.47802705
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-66000-20200314-0-00055445.fits
# For coadd:  coadd-66000-20200314-0-00055445.fits SN_z_spec fraction is =  0.470369
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-66014-20200314-5-00055433.fits
# For coadd:  coadd-66014-20200314-5-00055433.fits SN_z_spec fraction is =  0.470369
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-66003-20200315-0-00055654.fits
# For coadd:  coadd-66003-20200315-0-00055654.fits SN_z_spec fraction is =  0.470369
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-70510-20200304-7-00053086.fits
# For coadd:  coadd-70510-20200304-7-00053086.fits SN_z_spec fraction is =  0.470369
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-66014-20200314-0-00055433.fits
# For coadd:  coadd-66014-20200314-0-00055433.fits SN_z_spec fraction is =  0.470369
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-70510-20200304-0-00053081.fits
# For coadd:  coadd-70510-20200304-0-00053081.fits SN_z_spec fraction is =  0.470369
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-70500-20200303-0-00052935.fits
# For coadd:  coadd-70500-20200303-0-00052935.fits SN_z_spec fraction is =  0.470369
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-66000-20200314-2-00055444.fits
# For coadd:  coadd-66000-20200314-2-00055444.fits SN_z_spec fraction is =  0.470369
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-70510-20200304-6-00053090.fits
# For coadd:  coadd-70510-20200304-6-00053090.fits SN_z_spec fraction is =  0.470369
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-70500-20200303-0-00052934.fits
# For coadd:  coadd-70500-20200303-0-00052934.fits SN_z_spec fraction is =  0.470369
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-70500-20200303-9-00052932.fits
# For coadd:  coadd-70500-20200303-9-00052932.fits SN_z_spec fraction is =  0.470369
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-70502-20200225-3-00052116.fits
# For coadd:  coadd-70502-20200225-3-00052116.fits SN_z_spec fraction is =  0.470369
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-66000-20200314-7-00055445.fits
# For coadd:  coadd-66000-20200314-7-00055445.fits SN_z_spec fraction is =  0.470369
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-70500-20200303-0-00052940.fits
# For coadd:  coadd-70500-20200303-0-00052940.fits SN_z_spec fraction is =  0.470369
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-66014-20200314-2-00055432.fits
# For coadd:  coadd-66014-20200314-2-00055432.fits SN_z_spec fraction is =  0.4684633
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-66014-20200314-9-00055435.fits
# For coadd:  coadd-66014-20200314-9-00055435.fits SN_z_spec fraction is =  0.4684633
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-66000-20200314-5-00055444.fits
# For coadd:  coadd-66000-20200314-5-00055444.fits SN_z_spec fraction is =  0.4684633
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-70500-20200303-9-00052939.fits
# For coadd:  coadd-70500-20200303-9-00052939.fits SN_z_spec fraction is =  0.4684633
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-70500-20200303-0-00052933.fits
# For coadd:  coadd-70500-20200303-0-00052933.fits SN_z_spec fraction is =  0.4684633
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-70500-20200303-0-00052939.fits
# For coadd:  coadd-70500-20200303-0-00052939.fits SN_z_spec fraction is =  0.4684633
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-70500-20200303-6-00052936.fits
# For coadd:  coadd-70500-20200303-6-00052936.fits SN_z_spec fraction is =  0.4684633
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-70510-20200304-0-00053082.fits
# For coadd:  coadd-70510-20200304-0-00053082.fits SN_z_spec fraction is =  0.4684633
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-70500-20200303-6-00052932.fits
# For coadd:  coadd-70500-20200303-6-00052932.fits SN_z_spec fraction is =  0.4684633
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-70510-20200304-3-00053078.fits
# For coadd:  coadd-70510-20200304-3-00053078.fits SN_z_spec fraction is =  0.4684633
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-70502-20200225-6-00052090.fits
# For coadd:  coadd-70502-20200225-6-00052090.fits SN_z_spec fraction is =  0.4684633
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-70510-20200304-0-00053080.fits
# For coadd:  coadd-70510-20200304-0-00053080.fits SN_z_spec fraction is =  0.4684633
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-70510-20200304-6-00053080.fits
# For coadd:  coadd-70510-20200304-6-00053080.fits SN_z_spec fraction is =  0.4636226
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-66000-20200314-8-00055444.fits
# For coadd:  coadd-66000-20200314-8-00055444.fits SN_z_spec fraction is =  0.49717146
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-70510-20200304-6-00053081.fits
# For coadd:  coadd-70510-20200304-6-00053081.fits SN_z_spec fraction is =  0.49717146
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-66014-20200314-1-00055435.fits
# For coadd:  coadd-66014-20200314-1-00055435.fits SN_z_spec fraction is =  0.49717146
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-70500-20200303-0-00052938.fits
# For coadd:  coadd-70500-20200303-0-00052938.fits SN_z_spec fraction is =  0.49717146
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-66000-20200314-6-00055443.fits
# For coadd:  coadd-66000-20200314-6-00055443.fits SN_z_spec fraction is =  0.49717146
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-70502-20200225-0-00052113.fits
# For coadd:  coadd-70502-20200225-0-00052113.fits SN_z_spec fraction is =  0.49717146
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-70500-20200303-3-00052935.fits
# For coadd:  coadd-70500-20200303-3-00052935.fits SN_z_spec fraction is =  0.49717146
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-70500-20200303-3-00052939.fits
# For coadd:  coadd-70500-20200303-3-00052939.fits SN_z_spec fraction is =  0.49717146
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-70510-20200304-3-00053089.fits
# For coadd:  coadd-70510-20200304-3-00053089.fits SN_z_spec fraction is =  0.49717146
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-66003-20200315-1-00055656.fits
# For coadd:  coadd-66003-20200315-1-00055656.fits SN_z_spec fraction is =  0.49717146
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-66000-20200314-3-00055442.fits
# For coadd:  coadd-66000-20200314-3-00055442.fits SN_z_spec fraction is =  0.49717146
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-70502-20200225-0-00052114.fits
# For coadd:  coadd-70502-20200225-0-00052114.fits SN_z_spec fraction is =  0.49717146
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-70500-20200303-3-00052932.fits
# For coadd:  coadd-70500-20200303-3-00052932.fits SN_z_spec fraction is =  0.49717146
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-70500-20200303-0-00052941.fits
# For coadd:  coadd-70500-20200303-0-00052941.fits SN_z_spec fraction is =  0.49717146
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-70500-20200303-6-00052942.fits
# For coadd:  coadd-70500-20200303-6-00052942.fits SN_z_spec fraction is =  0.49187568
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-70510-20200304-0-00053084.fits
# For coadd:  coadd-70510-20200304-0-00053084.fits SN_z_spec fraction is =  0.49187568
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-66003-20200315-7-00055655.fits
# For coadd:  coadd-66003-20200315-7-00055655.fits SN_z_spec fraction is =  0.49187568
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-70500-20200303-6-00052933.fits
# For coadd:  coadd-70500-20200303-6-00052933.fits SN_z_spec fraction is =  0.49187562
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-70500-20200303-7-00052940.fits
# For coadd:  coadd-70500-20200303-7-00052940.fits SN_z_spec fraction is =  0.49187568
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-66014-20200314-1-00055434.fits
# For coadd:  coadd-66014-20200314-1-00055434.fits SN_z_spec fraction is =  0.49187568
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-66014-20200314-4-00055433.fits
# For coadd:  coadd-66014-20200314-4-00055433.fits SN_z_spec fraction is =  0.49187568
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-66003-20200315-2-00055655.fits
# For coadd:  coadd-66003-20200315-2-00055655.fits SN_z_spec fraction is =  0.49187562
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-70510-20200304-7-00053085.fits
# For coadd:  coadd-70510-20200304-7-00053085.fits SN_z_spec fraction is =  0.49187562
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-70510-20200304-0-00053078.fits
# For coadd:  coadd-70510-20200304-0-00053078.fits SN_z_spec fraction is =  0.49187562
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-66014-20200314-0-00055434.fits
# For coadd:  coadd-66014-20200314-0-00055434.fits SN_z_spec fraction is =  0.49187562
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-66014-20200314-4-00055434.fits
# For coadd:  coadd-66014-20200314-4-00055434.fits SN_z_spec fraction is =  0.49187562
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-70500-20200303-3-00052936.fits
# For coadd:  coadd-70500-20200303-3-00052936.fits SN_z_spec fraction is =  0.49187562
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-66000-20200314-5-00055445.fits
# For coadd:  coadd-66000-20200314-5-00055445.fits SN_z_spec fraction is =  0.49187562
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-66014-20200314-3-00055433.fits
# For coadd:  coadd-66014-20200314-3-00055433.fits SN_z_spec fraction is =  0.49187562
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-66000-20200314-8-00055445.fits
# For coadd:  coadd-66000-20200314-8-00055445.fits SN_z_spec fraction is =  0.5052303
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-70510-20200304-9-00053087.fits
# For coadd:  coadd-70510-20200304-9-00053087.fits SN_z_spec fraction is =  0.5052303
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-66014-20200314-9-00055434.fits
# For coadd:  coadd-66014-20200314-9-00055434.fits SN_z_spec fraction is =  0.5052303
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-66014-20200314-2-00055433.fits
# For coadd:  coadd-66014-20200314-2-00055433.fits SN_z_spec fraction is =  0.5028496
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-70500-20200303-0-00052942.fits
# For coadd:  coadd-70500-20200303-0-00052942.fits SN_z_spec fraction is =  0.5028496
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-70510-20200304-7-00053087.fits
# For coadd:  coadd-70510-20200304-7-00053087.fits SN_z_spec fraction is =  0.5028496
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-70510-20200304-9-00053085.fits
# For coadd:  coadd-70510-20200304-9-00053085.fits SN_z_spec fraction is =  0.5028496
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-70500-20200303-3-00052943.fits
# For coadd:  coadd-70500-20200303-3-00052943.fits SN_z_spec fraction is =  0.5028496
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-66003-20200315-6-00055656.fits
# For coadd:  coadd-66003-20200315-6-00055656.fits SN_z_spec fraction is =  0.5028496
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-66014-20200314-2-00055434.fits
# For coadd:  coadd-66014-20200314-2-00055434.fits SN_z_spec fraction is =  0.5028496
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-70500-20200303-6-00052937.fits
# For coadd:  coadd-70500-20200303-6-00052937.fits SN_z_spec fraction is =  0.49805257
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-66014-20200314-5-00055434.fits
# For coadd:  coadd-66014-20200314-5-00055434.fits SN_z_spec fraction is =  0.49805257
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-70510-20200304-6-00053084.fits
# For coadd:  coadd-70510-20200304-6-00053084.fits SN_z_spec fraction is =  0.49805257
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-66003-20200315-5-00055654.fits
# For coadd:  coadd-66003-20200315-5-00055654.fits SN_z_spec fraction is =  0.49805257
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-70510-20200304-0-00053087.fits
# For coadd:  coadd-70510-20200304-0-00053087.fits SN_z_spec fraction is =  0.49805257
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-70500-20200303-3-00052941.fits
# For coadd:  coadd-70500-20200303-3-00052941.fits SN_z_spec fraction is =  0.49805254
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-70500-20200303-0-00052932.fits
# For coadd:  coadd-70500-20200303-0-00052932.fits SN_z_spec fraction is =  0.49805257
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-66003-20200315-0-00055655.fits
# For coadd:  coadd-66003-20200315-0-00055655.fits SN_z_spec fraction is =  0.4941676
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-70510-20200304-0-00053090.fits
# For coadd:  coadd-70510-20200304-0-00053090.fits SN_z_spec fraction is =  0.49416763
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-70510-20200304-7-00053083.fits
# For coadd:  coadd-70510-20200304-7-00053083.fits SN_z_spec fraction is =  0.49416763
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-66003-20200315-7-00055656.fits
# For coadd:  coadd-66003-20200315-7-00055656.fits SN_z_spec fraction is =  0.49416763
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-70500-20200303-3-00052937.fits
# For coadd:  coadd-70500-20200303-3-00052937.fits SN_z_spec fraction is =  0.49416763
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-70510-20200304-7-00053090.fits
# For coadd:  coadd-70510-20200304-7-00053090.fits SN_z_spec fraction is =  0.49416763
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-66000-20200314-1-00055442.fits
# For coadd:  coadd-66000-20200314-1-00055442.fits SN_z_spec fraction is =  0.49416763
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-66003-20200315-9-00055655.fits
# For coadd:  coadd-66003-20200315-9-00055655.fits SN_z_spec fraction is =  0.49416763
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-66003-20200315-0-00055656.fits
# For coadd:  coadd-66003-20200315-0-00055656.fits SN_z_spec fraction is =  0.4893081
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-70500-20200303-9-00052941.fits
# For coadd:  coadd-70500-20200303-9-00052941.fits SN_z_spec fraction is =  0.4893081
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-70510-20200304-7-00053084.fits
# For coadd:  coadd-70510-20200304-7-00053084.fits SN_z_spec fraction is =  0.4852735
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-70500-20200303-7-00052941.fits
# For coadd:  coadd-70500-20200303-7-00052941.fits SN_z_spec fraction is =  0.4852735
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-70500-20200303-3-00052933.fits
# For coadd:  coadd-70500-20200303-3-00052933.fits SN_z_spec fraction is =  0.4852735
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-70500-20200303-3-00052934.fits
# For coadd:  coadd-70500-20200303-3-00052934.fits SN_z_spec fraction is =  0.48298094
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-66014-20200314-6-00055434.fits
# For coadd:  coadd-66014-20200314-6-00055434.fits SN_z_spec fraction is =  0.48298094
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-66000-20200314-7-00055443.fits
# For coadd:  coadd-66000-20200314-7-00055443.fits SN_z_spec fraction is =  0.48298097
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-70502-20200225-0-00052116.fits
# For coadd:  coadd-70502-20200225-0-00052116.fits SN_z_spec fraction is =  0.48298094
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-66000-20200314-1-00055444.fits
# For coadd:  coadd-66000-20200314-1-00055444.fits SN_z_spec fraction is =  0.47856233
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-70510-20200304-6-00053083.fits
# For coadd:  coadd-70510-20200304-6-00053083.fits SN_z_spec fraction is =  0.47856233
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-70510-20200304-0-00053088.fits
# For coadd:  coadd-70510-20200304-0-00053088.fits SN_z_spec fraction is =  0.47856233
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-70500-20200303-3-00052940.fits
# For coadd:  coadd-70500-20200303-3-00052940.fits SN_z_spec fraction is =  0.47856233
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-66000-20200314-9-00055442.fits
# For coadd:  coadd-66000-20200314-9-00055442.fits SN_z_spec fraction is =  0.47856233
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-70500-20200303-3-00052938.fits
# For coadd:  coadd-70500-20200303-3-00052938.fits SN_z_spec fraction is =  0.47856238
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-66014-20200314-6-00055435.fits
# For coadd:  coadd-66014-20200314-6-00055435.fits SN_z_spec fraction is =  0.47856238
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-70510-20200304-3-00053082.fits
# For coadd:  coadd-70510-20200304-3-00053082.fits SN_z_spec fraction is =  0.47425753
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-70500-20200303-6-00052943.fits
# For coadd:  coadd-70500-20200303-6-00052943.fits SN_z_spec fraction is =  0.47001103
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-70510-20200304-7-00053078.fits
# For coadd:  coadd-70510-20200304-7-00053078.fits SN_z_spec fraction is =  0.46565783
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-70510-20200304-3-00053084.fits
# For coadd:  coadd-70510-20200304-3-00053084.fits SN_z_spec fraction is =  0.4656578
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-66000-20200314-9-00055443.fits
# For coadd:  coadd-66000-20200314-9-00055443.fits SN_z_spec fraction is =  0.4656578
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-66000-20200314-7-00055444.fits
# For coadd:  coadd-66000-20200314-7-00055444.fits SN_z_spec fraction is =  0.46565783
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-66000-20200314-8-00055442.fits
# For coadd:  coadd-66000-20200314-8-00055442.fits SN_z_spec fraction is =  0.47415283
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-70510-20200304-3-00053080.fits
# For coadd:  coadd-70510-20200304-3-00053080.fits SN_z_spec fraction is =  0.47415283
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-70500-20200303-0-00052936.fits
# For coadd:  coadd-70500-20200303-0-00052936.fits SN_z_spec fraction is =  0.47415283
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-66003-20200315-4-00055656.fits
# For coadd:  coadd-66003-20200315-4-00055656.fits SN_z_spec fraction is =  0.47415283
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-70510-20200304-6-00053086.fits
# For coadd:  coadd-70510-20200304-6-00053086.fits SN_z_spec fraction is =  0.47415283
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-66000-20200314-2-00055445.fits
# For coadd:  coadd-66000-20200314-2-00055445.fits SN_z_spec fraction is =  0.47415283
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-66003-20200315-4-00055655.fits
# For coadd:  coadd-66003-20200315-4-00055655.fits SN_z_spec fraction is =  0.47415283
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-70502-20200225-7-00052113.fits
# For coadd:  coadd-70502-20200225-7-00052113.fits SN_z_spec fraction is =  0.47415283
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-70510-20200304-9-00053083.fits
# For coadd:  coadd-70510-20200304-9-00053083.fits SN_z_spec fraction is =  0.47415283
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-70502-20200225-9-00052113.fits
# For coadd:  coadd-70502-20200225-9-00052113.fits SN_z_spec fraction is =  0.47415283
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-66000-20200314-3-00055444.fits
# For coadd:  coadd-66000-20200314-3-00055444.fits SN_z_spec fraction is =  0.47415283
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-70500-20200303-9-00052943.fits
# For coadd:  coadd-70500-20200303-9-00052943.fits SN_z_spec fraction is =  0.47415283
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-66014-20200314-7-00055433.fits
# For coadd:  coadd-66014-20200314-7-00055433.fits SN_z_spec fraction is =  0.47397476
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-70510-20200304-7-00053089.fits
# For coadd:  coadd-70510-20200304-7-00053089.fits SN_z_spec fraction is =  0.47397476
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-70500-20200303-7-00052936.fits
# For coadd:  coadd-70500-20200303-7-00052936.fits SN_z_spec fraction is =  0.47397476
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-70500-20200303-9-00052942.fits
# For coadd:  coadd-70500-20200303-9-00052942.fits SN_z_spec fraction is =  0.47397476
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-70500-20200303-6-00052939.fits
# For coadd:  coadd-70500-20200303-6-00052939.fits SN_z_spec fraction is =  0.47397476
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-66000-20200314-6-00055445.fits
# For coadd:  coadd-66000-20200314-6-00055445.fits SN_z_spec fraction is =  0.47397476
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-66003-20200315-3-00055654.fits
# For coadd:  coadd-66003-20200315-3-00055654.fits SN_z_spec fraction is =  0.4714973
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-66014-20200314-1-00055433.fits
# For coadd:  coadd-66014-20200314-1-00055433.fits SN_z_spec fraction is =  0.4714973
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-66014-20200314-7-00055435.fits
# For coadd:  coadd-66014-20200314-7-00055435.fits SN_z_spec fraction is =  0.4714973
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-66003-20200315-9-00055656.fits
# For coadd:  coadd-66003-20200315-9-00055656.fits SN_z_spec fraction is =  0.4714973
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-66000-20200314-0-00055444.fits
# For coadd:  coadd-66000-20200314-0-00055444.fits SN_z_spec fraction is =  0.4714973
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-70510-20200304-9-00053089.fits
# For coadd:  coadd-70510-20200304-9-00053089.fits SN_z_spec fraction is =  0.4714973
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-66003-20200315-9-00055654.fits
# For coadd:  coadd-66003-20200315-9-00055654.fits SN_z_spec fraction is =  0.4714973
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-66000-20200314-3-00055443.fits
# For coadd:  coadd-66000-20200314-3-00055443.fits SN_z_spec fraction is =  0.4714973
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-70510-20200304-3-00053090.fits
# For coadd:  coadd-70510-20200304-3-00053090.fits SN_z_spec fraction is =  0.4714973
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-66014-20200314-8-00055433.fits
# For coadd:  coadd-66014-20200314-8-00055433.fits SN_z_spec fraction is =  0.48867193
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-70502-20200225-7-00052114.fits
# For coadd:  coadd-70502-20200225-7-00052114.fits SN_z_spec fraction is =  0.48867193
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-70502-20200225-7-00052115.fits
# For coadd:  coadd-70502-20200225-7-00052115.fits SN_z_spec fraction is =  0.48867193
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-70502-20200225-3-00052112.fits
# For coadd:  coadd-70502-20200225-3-00052112.fits SN_z_spec fraction is =  0.48867193
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-66000-20200314-1-00055445.fits
# For coadd:  coadd-66000-20200314-1-00055445.fits SN_z_spec fraction is =  0.48867193
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-66003-20200315-8-00055654.fits
# For coadd:  coadd-66003-20200315-8-00055654.fits SN_z_spec fraction is =  0.49430504
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-66014-20200314-6-00055432.fits
# For coadd:  coadd-66014-20200314-6-00055432.fits SN_z_spec fraction is =  0.49430504
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-70500-20200303-9-00052940.fits
# For coadd:  coadd-70500-20200303-9-00052940.fits SN_z_spec fraction is =  0.49430504
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-70510-20200304-9-00053088.fits
# For coadd:  coadd-70510-20200304-9-00053088.fits SN_z_spec fraction is =  0.49129972
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-70510-20200304-9-00053078.fits
# For coadd:  coadd-70510-20200304-9-00053078.fits SN_z_spec fraction is =  0.49129972
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-70502-20200225-9-00052115.fits
# For coadd:  coadd-70502-20200225-9-00052115.fits SN_z_spec fraction is =  0.49129972
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-70510-20200304-6-00053087.fits
# For coadd:  coadd-70510-20200304-6-00053087.fits SN_z_spec fraction is =  0.49129972
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-70500-20200303-7-00052932.fits
# For coadd:  coadd-70500-20200303-7-00052932.fits SN_z_spec fraction is =  0.49129972
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-66000-20200314-4-00055442.fits
# For coadd:  coadd-66000-20200314-4-00055442.fits SN_z_spec fraction is =  0.49129972
# found a coadds: /global/cfs/cdirs/desi/users/chahah/bgs_exp_coadd/coadd-66014-20200314-5-00055435.fits
# For coadd:  coadd-66014-20200314-5-00055435.fits SN_z_spec fraction is =  0.49129972

# %% [markdown]
# ### Putting all this information in a separate file for make future comparisons.

# %%
results=pd.DataFrame({'tile':tile, 'day':day, 'petalloc':petalloc, 'expid':expid, 'SN_frac':SN_frac, 'SN_z':SN_z, 'SN_z_std':SN_z_std})

# %%
plt.figure(figsize=(8,6))
plt.scatter(results["day"],results["SN_z"])
plt.ylabel("SN_frac",fontsize=15)
plt.xlabel("Night",fontsize=15)
plt.show()

# %%
results[0:5]
# Out:
#     tile       day petalloc  expid   SN_frac      SN_z  SN_z_std
# 0  66000  20200314        7  55442  4.854369       NaN       NaN
# 1  70510  20200304        6  53082  4.504505       NaN       NaN
# 2  66000  20200314        0  55442  4.201681       NaN       NaN
# 3  66014  20200314        8  55435  4.424779  0.637368  0.024925
# 4  66000  20200314        5  55442  3.816794  0.637368  0.022852

# %%
results.iloc[0][0]
# Out:
# '66000'

# %% [markdown]
# ### Now filtering for each coadd availables and matching with the onformation on observation conditions and stored all this information in a general file.

# %%
tile,day,petalloc,expid,SN_frac,SN_frac_std=[],[],[],[],[],[]
sky_mag_AB,airmass,contrast,transparency,fwhm_asec,program,fiber_fracflux,sky_mag_AB_per_amp,moon_sep_deg=[],[],[],[],[],[],[],[],[]
sky_mag_AB_std,airmass_std,contrast_std,transparency_std,fwhm_asec_std,fiber_fracflux_std,sky_mag_AB_per_amp_std,moon_sep_deg_std=[],[],[],[],[],[],[],[]
for r in np.arange(0,len(results),1):
    isnight=cond_SV2["NIGHT"]==int(results.iloc[r][1])
    ispetal=cond_SV2["PETAL_LOC"]==int(results.iloc[r][2])
    isexpid=cond_SV2["EXPID"]==int(results.iloc[r][3])
    if len(cond_SV2[isnight&ispetal&isexpid])>0:
        print("Coadd found (Night,Petal,ExpID,N)= ",int(results.iloc[r][1]),int(results.iloc[r][2]),int(results.iloc[r][3]),len(cond_SV2[isnight&ispetal&isexpid]))
        tile.append(results.iloc[r][0])
        day.append(results.iloc[r][1])
        petalloc.append(results.iloc[r][2])
        expid.append(results.iloc[r][3])
        SN_frac.append(results.iloc[r][5])
        SN_frac_std.append(results.iloc[r][6])
        sky_mag_AB.append(np.nanmean(cond_SV2[isnight&ispetal&isexpid]["SKY_MAG_AB"]))
        sky_mag_AB_per_amp.append(np.nanmean(cond_SV2[isnight&ispetal&isexpid]["SKY_MAG_AB_PER_AMP"]))
        moon_sep_deg.append(np.nanmean(cond_SV2[isnight&ispetal&isexpid]["MOON_SEP_DEG"]))
        airmass.append(np.nanmean(cond_SV2[isnight&ispetal&isexpid]["AIRMASS"]))
        contrast.append(np.nanmean(cond_SV2[isnight&ispetal&isexpid]["CONTRAST"]))
        transparency.append(np.nanmean(cond_SV2[isnight&ispetal&isexpid]["TRANSPARENCY"]))
        fwhm_asec.append(np.nanmean(cond_SV2[isnight&ispetal&isexpid]["FWHM_ASEC"]))
        fiber_fracflux.append(np.nanmean(cond_SV2[isnight&ispetal&isexpid]["FIBER_FRACFLUX"]))
        program.append((cond_SV2[isnight&ispetal&isexpid]["PROGRAM"][0]).split(" ")[0])
        sky_mag_AB_std.append(np.nanstd(cond_SV2[isnight&ispetal&isexpid]["SKY_MAG_AB"]))
        airmass_std.append(np.nanstd(cond_SV2[isnight&ispetal&isexpid]["AIRMASS"]))
        contrast_std.append(np.nanstd(cond_SV2[isnight&ispetal&isexpid]["CONTRAST"]))
        transparency_std.append(np.nanstd(cond_SV2[isnight&ispetal&isexpid]["TRANSPARENCY"]))
        fwhm_asec_std.append(np.nanstd(cond_SV2[isnight&ispetal&isexpid]["FWHM_ASEC"]))
        fiber_fracflux_std.append(np.nanstd(cond_SV2[isnight&ispetal&isexpid]["FIBER_FRACFLUX"]))
        sky_mag_AB_per_amp_std.append(np.nanstd(cond_SV2[isnight&ispetal&isexpid]["SKY_MAG_AB_PER_AMP"]))
        moon_sep_deg_std.append(np.nanstd(cond_SV2[isnight&ispetal&isexpid]["MOON_SEP_DEG"]))

tile,day,petalloc,expid,SN_frac=np.array(tile),np.array(day),np.array(petalloc),np.array(expid),np.array(SN_frac)
sky_mag_AB,airmass,contrast,transparency,fwhm_asec=np.array(sky_mag_AB),np.array(airmass),np.array(contrast),np.array(transparency),np.array(fwhm_asec)
sky_mag_AB_std,airmass_std,contrast_std=np.array(sky_mag_AB_std),np.array(airmass_std),np.array(contrast_std)
transparency_std,fwhm_asec_std=np.array(transparency_std),np.array(fwhm_asec_std)
program=np.array(program)
fiber_fracflux,fiber_fracflux_std=np.array(fiber_fracflux),np.array(fiber_fracflux_std)
results_all=pd.DataFrame({'program':program, 'tile':tile, 'day':day, 'petalloc':petalloc, 'expid':expid, 'SN_frac':SN_frac, 'SN_frac_std':SN_frac_std, 'sky_mag_AB':sky_mag_AB, 
                          'airmass':airmass, 'sky_mag_AB_per_amp':sky_mag_AB_per_amp, 'moon_sep_deg':moon_sep_deg,
                      'contrast':contrast, 'transparency':transparency, 'fwhm_asec':fwhm_asec, 'fiber_fracflux':fiber_fracflux, 'sky_mag_AB_std':sky_mag_AB_std, 
                          'airmass_std':airmass_std, 'contrast_std':contrast_std, 'transparency_std':transparency_std, 'fwhm_asec_std':fwhm_asec_std, 
                         'fiber_fracflux_std':fiber_fracflux_std, 'sky_mag_AB_per_amp_std':sky_mag_AB_per_amp_std, 'moon_sep_deg_std':moon_sep_deg_std})
# Out:
# Coadd found (Night,Petal,ExpID,N)=  20200304 3 53086 67
# Coadd found (Night,Petal,ExpID,N)=  20200225 7 52112 107
# Coadd found (Night,Petal,ExpID,N)=  20200304 3 53083 67
# Coadd found (Night,Petal,ExpID,N)=  20200304 0 53086 67
# Coadd found (Night,Petal,ExpID,N)=  20200303 7 52942 130
# Coadd found (Night,Petal,ExpID,N)=  20200304 7 53082 67
# Coadd found (Night,Petal,ExpID,N)=  20200304 7 53081 67
# Coadd found (Night,Petal,ExpID,N)=  20200304 0 53089 67
# Coadd found (Night,Petal,ExpID,N)=  20200304 3 53081 67
# Coadd found (Night,Petal,ExpID,N)=  20200303 3 52942 130
# Coadd found (Night,Petal,ExpID,N)=  20200304 7 53080 67
# Coadd found (Night,Petal,ExpID,N)=  20200303 7 52938 128
# Coadd found (Night,Petal,ExpID,N)=  20200304 3 53087 67
# Coadd found (Night,Petal,ExpID,N)=  20200304 3 53088 67
# Coadd found (Night,Petal,ExpID,N)=  20200304 7 53088 67
# Coadd found (Night,Petal,ExpID,N)=  20200225 7 52116 75
# Coadd found (Night,Petal,ExpID,N)=  20200304 0 53083 67
# Coadd found (Night,Petal,ExpID,N)=  20200225 3 52090 107
# Coadd found (Night,Petal,ExpID,N)=  20200225 0 52090 107
# Coadd found (Night,Petal,ExpID,N)=  20200225 7 52090 107
# Coadd found (Night,Petal,ExpID,N)=  20200225 3 52113 107
# Coadd found (Night,Petal,ExpID,N)=  20200225 0 52112 107
# Coadd found (Night,Petal,ExpID,N)=  20200304 0 53085 67
# Coadd found (Night,Petal,ExpID,N)=  20200225 3 52114 107
# Coadd found (Night,Petal,ExpID,N)=  20200303 7 52934 129
# Coadd found (Night,Petal,ExpID,N)=  20200225 3 52115 107
# Coadd found (Night,Petal,ExpID,N)=  20200304 3 53085 67
# Coadd found (Night,Petal,ExpID,N)=  20200225 0 52115 107
# Coadd found (Night,Petal,ExpID,N)=  20200304 7 53086 67
# Coadd found (Night,Petal,ExpID,N)=  20200304 0 53081 67
# Coadd found (Night,Petal,ExpID,N)=  20200303 0 52934 129
# Coadd found (Night,Petal,ExpID,N)=  20200225 3 52116 75
# Coadd found (Night,Petal,ExpID,N)=  20200303 0 52940 128
# Coadd found (Night,Petal,ExpID,N)=  20200304 0 53082 67
# Coadd found (Night,Petal,ExpID,N)=  20200304 3 53078 115
# Coadd found (Night,Petal,ExpID,N)=  20200304 0 53080 67
# Coadd found (Night,Petal,ExpID,N)=  20200303 0 52938 128
# Coadd found (Night,Petal,ExpID,N)=  20200225 0 52113 107
# Coadd found (Night,Petal,ExpID,N)=  20200304 3 53089 67
# Coadd found (Night,Petal,ExpID,N)=  20200225 0 52114 107
# Coadd found (Night,Petal,ExpID,N)=  20200303 3 52932 128
# Coadd found (Night,Petal,ExpID,N)=  20200304 0 53084 67
# Coadd found (Night,Petal,ExpID,N)=  20200303 7 52940 128
# Coadd found (Night,Petal,ExpID,N)=  20200304 7 53085 67
# Coadd found (Night,Petal,ExpID,N)=  20200304 0 53078 115
# Coadd found (Night,Petal,ExpID,N)=  20200303 3 52936 129
# Coadd found (Night,Petal,ExpID,N)=  20200303 0 52942 130
# Coadd found (Night,Petal,ExpID,N)=  20200304 7 53087 67
# Coadd found (Night,Petal,ExpID,N)=  20200304 0 53087 67
# Coadd found (Night,Petal,ExpID,N)=  20200303 0 52932 128
# Coadd found (Night,Petal,ExpID,N)=  20200304 0 53090 67
# Coadd found (Night,Petal,ExpID,N)=  20200304 7 53083 67
# Coadd found (Night,Petal,ExpID,N)=  20200304 7 53090 67
# Coadd found (Night,Petal,ExpID,N)=  20200304 7 53084 67
# Coadd found (Night,Petal,ExpID,N)=  20200303 3 52934 129
# Coadd found (Night,Petal,ExpID,N)=  20200225 0 52116 75
# Coadd found (Night,Petal,ExpID,N)=  20200304 0 53088 67
# Coadd found (Night,Petal,ExpID,N)=  20200303 3 52940 128
# Coadd found (Night,Petal,ExpID,N)=  20200303 3 52938 128
# Coadd found (Night,Petal,ExpID,N)=  20200304 3 53082 67
# Coadd found (Night,Petal,ExpID,N)=  20200304 7 53078 115
# Coadd found (Night,Petal,ExpID,N)=  20200304 3 53084 67
# Coadd found (Night,Petal,ExpID,N)=  20200304 3 53080 67
# Coadd found (Night,Petal,ExpID,N)=  20200303 0 52936 129
# Coadd found (Night,Petal,ExpID,N)=  20200225 7 52113 107
# Coadd found (Night,Petal,ExpID,N)=  20200304 7 53089 67
# Coadd found (Night,Petal,ExpID,N)=  20200303 7 52936 129
# Coadd found (Night,Petal,ExpID,N)=  20200304 3 53090 67
# Coadd found (Night,Petal,ExpID,N)=  20200225 7 52114 107
# Coadd found (Night,Petal,ExpID,N)=  20200225 7 52115 107
# Coadd found (Night,Petal,ExpID,N)=  20200225 3 52112 107
# Coadd found (Night,Petal,ExpID,N)=  20200303 7 52932 128

# %%
results_all
# Out:
#    program   tile       day petalloc  expid   SN_frac  SN_frac_std  \
# 0       MW  70510  20200304        3  53086  0.427712     0.031473
# 1       SV  70502  20200225        7  52112  0.541825     0.013156
# 2       MW  70510  20200304        3  53083  0.512394     0.012768
# 3       MW  70510  20200304        0  53086  0.485749     0.010701
# 4   MW+BGS  70500  20200303        7  52942  0.485749     0.010393
# ..     ...    ...       ...      ...    ...       ...          ...
# 67      MW  70510  20200304        3  53090  0.471497     0.003942
# 68      SV  70502  20200225        7  52114  0.488672     0.003947
# 69      SV  70502  20200225        7  52115  0.488672     0.003936
# 70      SV  70502  20200225        3  52112  0.488672     0.003927
# 71  MW+BGS  70500  20200303        7  52932  0.491300     0.003917
#
#     sky_mag_AB   airmass  sky_mag_AB_per_amp  ...  fwhm_asec  fiber_fracflux  \
# 0    20.148016  1.101940           20.148022  ...   0.963023        0.599304
# 1    21.492213  1.376164           21.492987  ...   2.946302        0.096774
# 2    20.017716  1.203612           20.018118  ...   0.986377        0.510226
# 3    20.060551  1.101940           20.060446  ...   1.001283        0.412456
# 4    19.621664  1.457899           19.621687  ...   1.326782        0.456350
# ..         ...       ...                 ...  ...        ...             ...
# 67   20.256145  1.026983           20.256048  ...   1.270571        0.452556
# 68   21.671269  1.253326           21.672688  ...   3.204566        0.082865
# 69   21.738764  1.219535           21.739464  ...   3.242456        0.074537
# 70   21.100657  1.376164           21.102617  ...   1.848260        0.246539
# 71   19.692786  1.136497           19.692766  ...   1.155365        0.525657
#
#     sky_mag_AB_std   airmass_std  contrast_std  transparency_std  \
# 0         0.041809  0.000000e+00      0.366971          0.152443
# 1         0.090498  6.661338e-16      0.700801         26.050800
# 2         0.037982  2.220446e-16      0.407109          0.139301
# 3         0.044258  0.000000e+00      0.554006          0.055657
# 4         0.016173  2.220446e-16      1.423998          0.015533
# ..             ...           ...           ...               ...
# 67        0.045217  2.220446e-16      0.446072          0.115181
# 68        0.139603  6.661338e-16      0.606747         48.037734
# 69        0.077166  4.440892e-16      0.763363         80.720234
# 70        0.113449  6.661338e-16      1.182180          0.211157
# 71        0.013637  0.000000e+00      1.524685          0.015441
#
#     fwhm_asec_std  fiber_fracflux_std  sky_mag_AB_per_amp_std  \
# 0        0.110252            0.119810                0.045005
# 1        0.676361            0.029085                0.102461
# 2        0.144246            0.094184                0.043120
# 3        0.112403            0.053003                0.045963
# 4        0.131471            0.061392                0.018410
# ..            ...                 ...                     ...
# 67       0.166601            0.089009                0.048472
# 68       0.682703            0.036916                0.146068
# 69       0.949207            0.126333                0.083313
# 70       0.582365            0.258675                0.119389
# 71       0.147213            0.084784                0.019721
#
#     moon_sep_deg_std
# 0           0.000041
# 1           0.016591
# 2           0.000044
# 3           0.000072
# 4           0.001015
# ..               ...
# 67          0.000083
# 68          0.011966
# 69          0.030322
# 70          0.008799
# 71          0.000928
#
# [72 rows x 23 columns]

# %%
vars=['sky_mag_AB', 'airmass', 'contrast', 'transparency', 'fwhm_asec', 'fiber_fracflux', 'sky_mag_AB_per_amp', 'moon_sep_deg']
objtype,spectype=["TGT","SKY"],["GALAXY","QSO","STAR"]
l_uno,l_dos=objtype[1],spectype[2]

# %%
for i in vars:
    plt.figure(figsize=(8,6))
    plt.errorbar(results_all[i],results_all["SN_frac"],yerr=(results_all["SN_frac_std"]), fmt='o',lw=1,label="(OBJTYPE=="+l_uno+") & (SPECTYPE=="+l_dos+")")
    plt.ylabel("SN_frac",fontsize=15)
    plt.xlabel(i,fontsize=15)
    plt.legend()
    plt.show()

# %%
plt.figure(figsize=(20,13))
plt.subplot(3, 3, 1)
plt.errorbar(results_all[vars[0]],results_all["SN_frac"],yerr=(results_all["SN_frac_std"]), fmt='o',lw=1,label="(OBJTYPE=="+l_uno+") & (SPECTYPE=="+l_dos+")")
plt.ylabel("SN_frac_z",fontsize=15)
plt.xlabel(vars[0],fontsize=15)
plt.legend()

plt.subplot(3, 3, 2)
plt.errorbar(results_all[vars[1]],results_all["SN_frac"],yerr=(results_all["SN_frac_std"]), fmt='o',lw=1,label="(OBJTYPE=="+l_uno+") & (SPECTYPE=="+l_dos+")")
plt.ylabel("SN_frac_z",fontsize=15)
plt.xlabel(vars[1],fontsize=15)
plt.legend()

plt.subplot(3, 3, 3)
plt.errorbar(results_all[vars[2]],results_all["SN_frac"],yerr=(results_all["SN_frac_std"]), fmt='o',lw=1,label="(OBJTYPE=="+l_uno+") & (SPECTYPE=="+l_dos+")")
plt.ylabel("SN_frac_z",fontsize=15)
plt.xlabel(vars[2],fontsize=15)
plt.legend()

plt.subplot(3, 3, 4)
plt.errorbar(results_all[vars[3]],results_all["SN_frac"],yerr=(results_all["SN_frac_std"]), fmt='o',lw=1,label="(OBJTYPE=="+l_uno+") & (SPECTYPE=="+l_dos+")")
plt.ylabel("SN_frac_z",fontsize=15)
plt.xlabel(vars[3],fontsize=15)
plt.legend()

plt.subplot(3, 3, 5)
plt.errorbar(results_all[vars[4]],results_all["SN_frac"],yerr=(results_all["SN_frac_std"]), fmt='o',lw=1,label="(OBJTYPE=="+l_uno+") & (SPECTYPE=="+l_dos+")")
plt.ylabel("SN_frac_z",fontsize=15)
plt.xlabel(vars[4],fontsize=15)
plt.legend()

plt.subplot(3, 3, 6)
plt.errorbar(results_all[vars[5]],results_all["SN_frac"],yerr=(results_all["SN_frac_std"]), fmt='o',lw=1,label="(OBJTYPE=="+l_uno+") & (SPECTYPE=="+l_dos+")")
plt.ylabel("SN_frac_z",fontsize=15)
plt.xlabel(vars[5],fontsize=15)
plt.legend()

plt.subplot(3, 3, 7)
plt.errorbar(results_all[vars[6]],results_all["SN_frac"],yerr=(results_all["SN_frac_std"]), fmt='o',lw=1,label="(OBJTYPE=="+l_uno+") & (SPECTYPE=="+l_dos+")")
plt.ylabel("SN_frac_z",fontsize=15)
plt.xlabel(vars[6],fontsize=15)
plt.legend()

plt.subplot(3, 3, 8)
plt.errorbar(results_all[vars[7]],results_all["SN_frac"],yerr=(results_all["SN_frac_std"]), fmt='o',lw=1,label="(OBJTYPE=="+l_uno+") & (SPECTYPE=="+l_dos+")")
plt.ylabel("SN_frac_z",fontsize=15)
plt.xlabel(vars[7],fontsize=15)
plt.legend()

plt.show()
